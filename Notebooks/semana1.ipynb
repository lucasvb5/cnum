# %% [markdown]
# # Atividade 1

# %% [markdown]
# Faça na linguagem python uma função que calcula as raizes da equação do segundo grau.
#
# Serão passados os coeficientes a, b e c. Caso a = 0. resolva como uma equação do primeiro grau, e se b = 0 gere uma exceção.

# %% [markdown]
# # Importando uma biblioteca
# Código usado para importar uma biblioteca específica do python.

# %%
from math import sqrt

# %% [markdown]
# # Criando uma função
# Raiz de equação quadrática

# %%
def zeros(a,b,c): 

        if a == 0 
            raise ValueError("a equação não é de segundo grau")
        else :
             return [-c/b]    

    delta = b**2 - (4*a*c)
    if delta < 0:
            return None
    elif delta == 0:
        x = -b / (2*a)
        return[x,x]
    else:
        x1 =(-b +sqrt(delta)) / (2*a)
        x2 =(-b - delta**0.5) / (2*a)
        return[x1,x2]

# %% [markdown]
# # Executando o código
# Criando a função principal

# %%
def main():
    x = zeros(1,-5,6)
    print(x)

if  __name__ == "__main__":
    main()
